# %% [markdown]
# <a href="https://colab.research.google.com/github/JyothiSTheagarajan/LMS/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Student ID']
  ys = series['Midterm Grade']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = students_df.sort_values('Student ID', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Student ID')
_ = plt.ylabel('Midterm Grade')

# %%
# Create new student data
new_student_data = {
    'Student ID': [113, 114, 115],
    'Name': ['Ruchi', 'Noah', 'Olivia'],
    'Age': [19, 21, 19],
    'Midterm Grade': [98, 76, 95]
}

new_students_df = pd.DataFrame(new_student_data)

# Add the new students to the existing DataFrame
students_df = pd.concat([students_df, new_students_df], ignore_index=True)

# Display the updated DataFrame
display(students_df)
# Out:
#     Student ID     Name  Age  Midterm Grade
# 0          101    Alice   20             90
# 1          102      Bob   19             86
# 2          103  Charlie   24             79
# 3          104    David   24             69
# 4          105      Eve   20             68
# 5          106    Frank   20             66
# 6          107    Grace   23             77
# 7          108    Heidi   21             91
# 8          109     Ivan   24             92
# 9          110     Judy   19             90
# 10         111    Kevin   19             85
# 11         112     Liam   18             89
# 12         113    Ruchi   20             88
# 13         114     Noah   21             76
# 14         115   Olivia   19             95
# 15         113    Ruchi   19             98
# 16         114     Noah   21             76
# 17         115   Olivia   19             95
